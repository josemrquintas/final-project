# %%
import pandas as pd
import random
import tweepy
import random
import time
import GetOldTweets3 as got

# %%
consumer_key = "xMqbF6gGhWHWPUg9xw5ziJZpK"
consumer_secret = "RPGgCCRFD2VpyfcPpEVjPbCYPlFIi2cTEImz6BNWzkIXGekibx"
access_key = "1119208863574708224-FwHs7oMskXgPAocqA81D5HrOdwV6tA"
access_token = "1119208863574708224-FwHs7oMskXgPAocqA81D5HrOdwV6tA"
access_secret = "hmlim46RNtaHkFBIHWYYKACAKsUtvsu59YViEjW0bnZ2J"
access_token_secret = "hmlim46RNtaHkFBIHWYYKACAKsUtvsu59YViEjW0bnZ2J"

# %%
ironhack = pd.read_csv('/home/jose/Documents/Ironhack/Projects/Final Project/final-project/your-project/notebooks/main/Ironhack/ironhack_twitter_community.csv')
ironhack.describe()
# Out:
#          Unnamed: 0            id  followers_count  friends_count  \
# count  12205.000000  1.220500e+04     1.220500e+04   12205.000000
# mean    6102.000000  1.435787e+17     1.916582e+03    1646.180090
# std     3523.424352  3.247707e+17     2.842752e+04    8315.578048
# min        0.000000  1.353200e+04     0.000000e+00       1.000000
# 25%     3051.000000  1.407636e+08     7.300000e+01     245.000000
# 50%     6102.000000  5.245893e+08     2.440000e+02     625.000000
# 75%     9153.000000  3.063833e+09     7.060000e+02    1450.000000
# max    12204.000000  1.232369e+18     2.878503e+06  401962.000000
#
#        listed_count  favourites_count  statuses_count
# count  12205.000000      12205.000000    1.220500e+04
# mean      62.505039       2891.769111    4.941899e+03
# std      256.063195      11774.755447    2.221246e+04
# min        0.000000          0.000000    0.000000e+00
# 25%        1.000000         52.000000    1.340000e+02
# 50%        9.000000        382.000000    7.930000e+02
# 75%       40.000000       1842.000000    3.307000e+03
# max     9764.000000     597215.000000    1.049781e+06

# %%
ironhack_true = ironhack[ironhack['protected']==False]

# %%
ironhack_q3 = ironhack_true[(ironhack['statuses_count'] >=793)&
                            (ironhack['statuses_count']<=3307)]

ironhack_q3.head()
# Out:
# /home/jose/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     Unnamed: 0                   id      screen_name                 location  \
# 8            8            623370781  estebanquirogas                   México
# 10          10            228463269         dzubilla  México Distrito Federal
# 12          12            236532231    Lowenmensch22               Austin, TX
# 25          25            185898028   EngAbdulaziz95                   Jeddah
# 27          27  1134815199440134147  MagaliMilbergue    Ile-de-France, France
#
#     protected  verified  followers_count  friends_count  listed_count  \
# 8       False     False              615            269             0
# 10      False     False              297            683             4
# 12      False     False              206           2103             0
# 25      False     False              124            346             2
# 27      False     False              308            284             4
#
#     favourites_count  statuses_count                      created_at  \
# 8               5926             822  Sun Jul 01 03:23:53 +0000 2012
# 10              1191            2174  Sun Dec 19 20:04:11 +0000 2010
# 12              8591            1872  Mon Jan 10 20:16:50 +0000 2011
# 25               517            1453  Thu Sep 02 02:42:46 +0000 2010
# 27             22522            3288  Sat Jun 01 13:33:22 +0000 2019
#
#     default_profile  default_profile_image
# 8             False                  False
# 10             True                  False
# 12             True                  False
# 25            False                  False
# 27            False                  False

# %%
def top_function(username): # date format = "2019-08-28"
    username = username
    count = 20# Creation of query object
    tweetCriteria = got.manager.TweetCriteria().setUsername(username)\
                                        .setMaxTweets(count)
    # Creation of list that contains all tweets
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)# Creating list of chosen tweet data
    user_tweets = [[tweet.text, tweet.hashtags] for tweet in tweets]
    
    return user_tweets

# %%
#ironhack_q3['applying_function'] = ironhack_q3['screen_name'].apply(top_function)

list_user_tweets = []
count = 0
for x in ironhack_q3['screen_name']  :
    count += 1
    print('Scrapping username number:', count)
    user_tweets = top_function(x)
    list_user_tweets.append(user_tweets)
# Out:
# Scrapping username number: 1
# Scrapping username number: 2
# Scrapping username number: 3
# Scrapping username number: 4
# Scrapping username number: 5
# Scrapping username number: 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-d2e1e32709c6> in <module>
#       6     count += 1
#       7     print('Scrapping username number:', count)
# ----> 8     user_tweets = top_function(x)
#       9     list_user_tweets.append(user_tweets)
#      10
#
# <ipython-input-16-a4d76199ecb6> in top_function(username)
#       5                                         .setMaxTweets(count)
#       6     # Creation of list that contains all tweets
# ----> 7     tweets = got.manager.TweetManager.getTweets(tweetCriteria)# Creating list of chosen tweet data
#       8     user_tweets = [[tweet.text, tweet.hashtags] for tweet in tweets]
#       9
#
# ~/anaconda3/lib/python3.7/site-packages/GetOldTweets3/manager/TweetManager.py in getTweets(tweetCriteria, receiveBuffer, bufferLength, proxy, debug)
#      63             active = True
#      64             while active:
# ---> 65                 json = TweetManager.getJsonResponse(tweetCriteria, refreshCursor, cookieJar, proxy, user_agent, debug=debug)
#      66                 if len(json['items_html'].strip()) == 0:
#      67                     break
#
# ~/anaconda3/lib/python3.7/site-packages/GetOldTweets3/manager/TweetManager.py in getJsonResponse(tweetCriteria, refreshCursor, cookieJar, proxy, useragent, debug)
#     341
#     342         try:
# --> 343             response = opener.open(url)
#     344             jsonResponse = response.read()
#     345         except Exception as e:
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1360         def https_open(self, req):
#    1361             return self.do_open(http.client.HTTPSConnection, req,
# -> 1362                 context=self._context, check_hostname=self._check_hostname)
#    1363
#    1364         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317             try:
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#    1321                 raise URLError(err)
#
# ~/anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1250                 encode_chunked=False):
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#    1254     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1296             # default charset of iso-8859-1.
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#    1300     def getresponse(self):
#
# ~/anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1245         else:
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#    1249     def request(self, method, url, body=None, headers={}, *,
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# ~/anaconda3/lib/python3.7/http/client.py in send(self, data)
#     964         if self.sock is None:
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#     968                 raise NotConnected()
#
# ~/anaconda3/lib/python3.7/http/client.py in connect(self)
#    1412             "Connect to a host on a given (SSL) port."
#    1413
# -> 1414             super().connect()
#    1415
#    1416             if self._tunnel_host:
#
# ~/anaconda3/lib/python3.7/http/client.py in connect(self)
#     936         """Connect to the host and port specified in __init__."""
#     937         self.sock = self._create_connection(
# --> 938             (self.host,self.port), self.timeout, self.source_address)
#     939         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#     940
#
# ~/anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:

# %%
def top_function(users, start, end): # date format = "2019-08-28"
    count = 0
    tweets_for_dataframe = []
    print('Retrieving data from', len(users),'users.','\n','Starting now.')
    
    
    for username in users: 
        
        time.sleep(random.randrange(0, 1))
        
        tweetCriteria = got.manager.TweetCriteria().setUsername(username)\
                                               .setSince(start)\
                                               .setUntil(end)\
                                               .setMaxTweets(100)\
                                               .setEmoji("unicode")
        tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        
        count+=1
        print('Currently at number', count, '\n', 'Percentage completed: ', (count/len(users)))
    
        for tweet in tweets: 
            tweets_for_dataframe.append([username, tweet.id, tweet.to, tweet.date, tweet.text, tweet.retweets, tweet.favorites, tweet.mentions, tweet.hashtags, tweet.geo])
        
        ds = pd.DataFrame(tweets_for_dataframe, columns = ['user','tweet_id','directed_at','tweet_date', 'text', 'rwtweets','favorites','mentions','hashtags','geo'])
        
    return ds

# %%
for k in range(15550,15555): 
    username = meo_followers['screen_name']
    start = '2020-02-01'
    end = '2020-03-01'
    tweets_for_dataframe = []
    ds = pd.DataFrame(columns = ['user','tweet_id','directed_at','tweet_date', 'text', 'retweets','favorites','mentions','hashtags','geo'])

    tweetCriteria = got.manager.TweetCriteria().setUsername(username[k])\
                                               .setSince(start)\
                                               .setUntil(end)\
                                               .setMaxTweets(100)\
                                               .setEmoji("unicode")
    
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    
    for tweet in tweets: 
        tweets_for_dataframe.append([username, tweet.id, tweet.to, tweet.date, tweet.text, tweet.retweets, tweet.favorites, tweet.mentions, tweet.hashtags, tweet.geo])
    
    data = pd.DataFrame(tweets_for_dataframe, columns = ['user','tweet_id','directed_at','tweet_date', 'text', 'retweets','favorites','mentions','hashtags','geo'])

# %%
def real_top_function(users, start, end): # date format = "2019-08-28"
    count = 0
    tweets_for_dataframe = []
    print('Retrieving data from', len(users),'users.','\n','Starting now.')
    
    
    for username in users['screen_name']: 
        time.sleep(random.randrange(0, 1))
        tweetCriteria = got.manager.TweetCriteria().setUsername(username)\
                                               .setSince(start)\
                                               .setUntil(end)\
                                               .setMaxTweets(1000)\
                                               .setEmoji("unicode")
        tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        
        count+=1
        print('Currently at number', count, '\n', 'Percentage completed: ', (count/len(users)))
    
        for tweet in tweets: 
            tweets_for_dataframe.append([username, tweet.id, tweet.to, tweet.date, tweet.text, tweet.retweets, 
                                         tweet.favorites, tweet.mentions, tweet.hashtags, tweet.geo])
        
        ds = pd.DataFrame(tweets_for_dataframe, columns = ['user','tweet_id','directed_at','tweet_date', 'text', 
                                                           'rwtweets','favorites','mentions','hashtags','geo'])
        
    return ds

# %%
data.head()
# Out:
# Empty DataFrame
# Columns: [user, tweet_id, directed_at, tweet_date, text, retweets, favorites, mentions, hashtags, geo]
# Index: []

# %%
data
# Out:
# Empty DataFrame
# Columns: [user, tweet_id, directed_at, tweet_date, text, retweets, favorites, mentions, hashtags, geo]
# Index: []

# %%
meo_followers[400:600]
# Out:
#                       id      screen_name                  location  \
# 400  1195704796839366656          SMR_zx6                       NaN
# 401  1230881858801397761      ridasyariff                       NaN
# 402  1230879221930741760       Evanceayo6                       NaN
# 403  1230873647348355073   SBilal74846660        Fez, Fès-Boulemane
# 404  1174959790490976256  RafaelV85328975                       NaN
# ..                   ...              ...                       ...
# 595            160287231         Kid4Poke  Comi cu de quem ta lendo
# 596  1222008865765707776  Guilher26535539             Planeta Terra
# 597  1120034751614783488   mertcansahinbu                       NaN
# 598  1226730515090362373       BahjaOmar4                       NaN
# 599  1227316385895927818  Brookly04126883                       NaN
#
#      followers_count  verified  statuses_count
# 400               86     False             143
# 401                0     False               1
# 402                1     False               0
# 403                2     False               1
# 404               89     False             284
# ..               ...       ...             ...
# 595             2502     False           96458
# 596              118     False              28
# 597              546     False              70
# 598                1     False              14
# 599                7     False              38
#
# [200 rows x 6 columns]

# %%
complete_dataframe = pd.DataFrame(columns = ['user','tweet_id','directed_at','tweet_date', 'text', 
                                            'rwtweets','favorites','mentions','hashtags','geo'])

complete_dataframe
# Out:
# Empty DataFrame
# Columns: [user, tweet_id, directed_at, tweet_date, text, rwtweets, favorites, mentions, hashtags, geo]
# Index: []

# %%
meo_followers.shape[0]
# Out:
# 29552

# %%
import getpass
import os
password  = '11519205'

for k in range(0,4):
    print('Starting Round', k)
    complete_dataframe.append(real_top_function(meo_followers[(0+2*k):(2+2*k)], '2020-02-01', '2020-03-01'))

    # !echo '11519205' | sudo -S ifconfig eth0 down
    
    # !echo '11519205' | sudo -S ifconfig et0 192.168.(random.randrange(0,255).random.randrange(0,255))
   
    # !echo '11519205' | sudo -S ifconfig eth0 up

    print('ip changed')
    time.sleep((5))
    
    
    complete_dataframe.to_csv(str('copy'+str(k)+'.csv'))
# Out:
# Starting Round 0
# Retrieving data from 2 users.
#  Starting now.
# Currently at number 1
#  Percentage completed:  0.5
# Currently at number 2
#  Percentage completed:  1.0
# [sudo] password for jose: sudo: ifconfig: command not found
# /bin/sh: 1: Syntax error: "(" unexpected
# [sudo] password for jose: sudo: ifconfig: command not found
# ip changed
# Starting Round 1
# Retrieving data from 2 users.
#  Starting now.
# Currently at number 1
#  Percentage completed:  0.5
# Currently at number 2
#  Percentage completed:  1.0
# [sudo] password for jose: sudo: ifconfig: command not found
# /bin/sh: 1: Syntax error: "(" unexpected
# [sudo] password for jose: sudo: ifconfig: command not found
# ip changed
# Starting Round 2
# Retrieving data from 2 users.
#  Starting now.
# Currently at number 1
#  Percentage completed:  0.5
# Currently at number 2
#  Percentage completed:  1.0
# [sudo] password for jose: sudo: ifconfig: command not found
# /bin/sh: 1: Syntax error: "(" unexpected
# [sudo] password for jose: sudo: ifconfig: command not found
# ip changed
# Starting Round 3
# Retrieving data from 2 users.
#  Starting now.
# Currently at number 1
#  Percentage completed:  0.5
# Currently at number 2
#  Percentage completed:  1.0
# [sudo] password for jose: sudo: ifconfig: command not found
# /bin/sh: 1: Syntax error: "(" unexpected
# [sudo] password for jose: sudo: ifconfig: command not found
# ip changed

# %%
complete_dataframe.head()
